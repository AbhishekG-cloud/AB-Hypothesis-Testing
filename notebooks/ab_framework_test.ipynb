# %%
import sys
from pathlib import Path

project_root = Path.cwd().parent
sys.path.append(str(project_root))
from src.ab_framework import ABTestFramework

framework = ABTestFramework()

results = framework.run_full_analysis(
    n_A=1000,
    conv_A=120,
    n_B=1000,
    conv_B=121,
)

results
# Out:
# {'frequentist': {'z_statistic': np.float64(0.06868684317722049),
#   'p_value': np.float64(0.9452388910924663),
#   'confidence_interval': (np.float64(-0.027534746716512237),
#    np.float64(0.02953474671651224)),
#   'decision': 'Fail to Reject H0'},
#  'bayesian': {'A': {'posterior_params': (121.0, 881.0),
#    'mean': 0.12075848303393213,
#    'mode': 0.12,
#    'credible_interval': (np.float64(0.10132341964422845),
#     np.float64(0.1416269997488508))},
#   'B': {'posterior_params': (122.0, 880.0),
#    'mean': 0.1217564870259481,
#    'mode': 0.121,
#    'credible_interval': (np.float64(0.10224781023935217),
#     np.float64(0.14269485177512925))}},
#  'monte_carlo': {'probability_B_beats_A': np.float64(0.52638),
#   'expected_uplift': np.float64(0.0009139873678690111),
#   'expected_loss': np.float64(0.005344674653699857)},
#  'recommendation': {'recommendation': 'Keep Variant A',
#   'reason': 'Neither Frequentist nor Bayesian evidence supports Variant B.'}}

# %%
framework = ABTestFramework()

results = framework.run_full_analysis(
    n_A=1000,
    conv_A=120,
    n_B=1000,
    conv_B=130,
)

results
# Out:
# {'frequentist': {'z_statistic': np.float64(0.6761234037828139),
#   'p_value': np.float64(0.4989622986037605),
#   'confidence_interval': (np.float64(-0.018984945128217936),
#    np.float64(0.03898494512821796)),
#   'decision': 'Fail to Reject H0'},
#  'bayesian': {'A': {'posterior_params': (121.0, 881.0),
#    'mean': 0.12075848303393213,
#    'mode': 0.12,
#    'credible_interval': (np.float64(0.10132341964422845),
#     np.float64(0.1416269997488508))},
#   'B': {'posterior_params': (131.0, 871.0),
#    'mean': 0.13073852295409183,
#    'mode': 0.13,
#    'credible_interval': (np.float64(0.11058665388805142),
#     np.float64(0.1522861853527265))}},
#  'monte_carlo': {'probability_B_beats_A': np.float64(0.7479),
#   'expected_uplift': np.float64(0.009870079673133967),
#   'expected_loss': np.float64(0.002175619799002563)},
#  'recommendation': {'recommendation': 'Keep Variant A',
#   'reason': 'Neither Frequentist nor Bayesian evidence supports Variant B.'}}

# %%
framework = ABTestFramework()

results = framework.run_full_analysis(
    n_A=1000,
    conv_A=120,
    n_B=1000,
    conv_B=180,
)

results
# Out:
# {'frequentist': {'z_statistic': np.float64(3.757345746510896),
#   'p_value': np.float64(0.00017172515611352246),
#   'confidence_interval': (np.float64(0.028812544614865536),
#    np.float64(0.09118745538513445)),
#   'decision': 'Reject H0'},
#  'bayesian': {'A': {'posterior_params': (121.0, 881.0),
#    'mean': 0.12075848303393213,
#    'mode': 0.12,
#    'credible_interval': (np.float64(0.10132341964422845),
#     np.float64(0.1416269997488508))},
#   'B': {'posterior_params': (181.0, 821.0),
#    'mean': 0.18063872255489022,
#    'mode': 0.18,
#    'credible_interval': (np.float64(0.1574441611695768),
#     np.float64(0.20504063464993905))}},
#  'monte_carlo': {'probability_B_beats_A': np.float64(0.99992),
#   'expected_uplift': np.float64(0.05986937332170561),
#   'expected_loss': np.float64(2.8892370782521435e-07)},
#  'recommendation': {'recommendation': 'Launch Variant B',
#   'reason': 'Frequentist significance achieved, Bayesian confidence is high, and expected loss is negligible.'}}
